# %% [markdown]
# Proyecto tarea sumativa 1

# %%
import sys
import os
 
# subir un nivel y entrar a src
ruta = os.path.abspath("../src")
sys.path.append(ruta)

from function import cargar_datos


ds = cargar_datos('../data/raw/AI_Impact_on_Jobs_2030.csv')
print(ds.shape, ds.dtypes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 8
#       4 # subir un nivel y entrar a src
#       5 ruta = os.path.abspath("../src")
#       6 sys.path.append(ruta)
#       7
# ----> 8 from function import cargar_datos
#       9
#      10
#      11 ds = cargar_datos('../data/raw/AI_Impact_on_Jobs_2030.csv')
#
# File c:\Users\RMoncada\mcdi500_1\src\function.py:7
#       4     """Lee el dataset y devuelve un DataFrame."""
#       5     return pd.read_csv(ruta)
# ----> 7 df = cargar_datos('data/raw/AI_Impact_on_Jobs_2030.csv')
#       8 print(df.shape, df.dtypes)
#
# File c:\Users\RMoncada\mcdi500_1\src\function.py:5, in cargar_datos(ruta)
#       3 def cargar_datos(ruta):
#       4     """Lee el dataset y devuelve un DataFrame."""
# ----> 5     return pd.read_csv(ruta)
#
# ...
