# %% [markdown]
# Creación de codigo de ciencia de datos

# %%
    import sys
    import os
    
    # subir un nivel y entrar a src"
    ruta = os.path.abspath("../src")
    sys.path.append(ruta)
    
    from function import cargar_datos

    #llamada funcion
    ds = cargar_datos('../data/raw/AI_Impact_on_Jobs_2030.csv')
    print(ds.shape, ds.dtypes)
# Out:
# (3000, 18) Job_Title                          str
# Average_Salary                   int64
# Years_Experience                 int64
# Education_Level                    str
# AI_Exposure_Index              float64
# Tech_Growth_Factor             float64
# Automation_Probability_2030    float64
# Risk_Category                      str
# Skill_1                        float64
# Skill_2                        float64
# Skill_3                        float64
# Skill_4                        float64
# Skill_5                        float64
# Skill_6                        float64
# Skill_7                        float64
# Skill_8                        float64
# Skill_9                        float64
# Skill_10                       float64
# dtype: object
